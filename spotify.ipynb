# %%
# pip install spotipy

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
# authentication
client_credentials_manager = SpotifyClientCredentials(client_id="8252b515977848aa98e73419635b1cdf",
                                                      client_secret = "c851925e590447288b9ec8a13fb79a97")

# %%
# authorization
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
playlist_link = "https://open.spotify.com/playlist/3IsxzDS04BvejFJcQ0iVyW"

# %%
playlist_URI = playlist_link.split('/')[-1]
playlist_URI
# Out:
# '3IsxzDS04BvejFJcQ0iVyW'

# %%
data = sp.playlist_tracks(playlist_URI)
data
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/3IsxzDS04BvejFJcQ0iVyW/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2023-05-16T06:56:13Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/4mpi68xfuac3mv28sgxehm7o0'},
#     'href': 'https://api.spotify.com/v1/users/4mpi68xfuac3mv28sgxehm7o0',
#     'id': '4mpi68xfuac3mv28sgxehm7o0',
#     'type': 'user',
#     'uri': 'spotify:user:4mpi68xfuac3mv28sgxehm7o0'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3hcs9uc56yIGFCSy9leWe7'},
#        'href': 'https://api.spotify.com/v1/artists/3hcs9uc56yIGFCSy9leWe7',
#        'id': '3hcs9uc56yIGFCSy9leWe7',
#        'name': 'Lil Durk',
#        'type': 'artist',
#        'uri': 'spotify:artist:3hcs9uc56yIGFCSy9leWe7'},
# ...

# %%
data['items'][0]['track']['album']['id']
# Out:
# '0lZQagJ5r0crB35zphSD4A'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'All My Life (feat. J. Cole)'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2023-05-12'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 1

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/0lZQagJ5r0crB35zphSD4A'

# %%
album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    album_elements = {'album_id': album_id,
                     'album_name': album_name,
                     'album_release_date': album_release_date,
                     'album_total_tracks': album_total_tracks,
                     'album_url': album_url}
    album_list.append(album_elements)

# %%
album_list
# Out:
# [{'album_id': '0lZQagJ5r0crB35zphSD4A',
#   'album_name': 'All My Life (feat. J. Cole)',
#   'album_release_date': '2023-05-12',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/0lZQagJ5r0crB35zphSD4A'},
#  {'album_id': '7fOmdhRrRohTzToL617xkk',
#   'album_name': '3 Songs At A Time Sampler',
#   'album_release_date': '2023-01-31',
#   'album_total_tracks': 3,
#   'album_url': 'https://open.spotify.com/album/7fOmdhRrRohTzToL617xkk'},
#  {'album_id': '7yMkS4NCpG0FH6NoaH3F0a',
#   'album_name': 'アイドル',
#   'album_release_date': '2023-04-12',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/7yMkS4NCpG0FH6NoaH3F0a'},
#  {'album_id': '3Mm1P5CEEAiuJqBclr2EyU',
#   'album_name': 'Ella Baila Sola',
#   'album_release_date': '2023-03-16',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/3Mm1P5CEEAiuJqBclr2EyU'},
#  {'album_id': '67WUCOjyl44d8fAFzHONjW',
#   'album_name': 'Search & Rescue',
# ...

# %%
data['items'][0]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3hcs9uc56yIGFCSy9leWe7'},
#   'href': 'https://api.spotify.com/v1/artists/3hcs9uc56yIGFCSy9leWe7',
#   'id': '3hcs9uc56yIGFCSy9leWe7',
#   'name': 'Lil Durk',
#   'type': 'artist',
#   'uri': 'spotify:artist:3hcs9uc56yIGFCSy9leWe7'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/6l3HvQ5sa6mXTsMTB19rO5'},
#   'href': 'https://api.spotify.com/v1/artists/6l3HvQ5sa6mXTsMTB19rO5',
#   'id': '6l3HvQ5sa6mXTsMTB19rO5',
#   'name': 'J. Cole',
#   'type': 'artist',
#   'uri': 'spotify:artist:6l3HvQ5sa6mXTsMTB19rO5'}]

# %%
artist_list = []
for row in data['items']:
    for key, value in row.items():
        if key=='track':
            for artist in value['artists']:
                artist_dict = {'artist_id': artist['id'], 
                               'artist_name': artist['name'], 
                               'external_url': artist['href']}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '3hcs9uc56yIGFCSy9leWe7',
#   'artist_name': 'Lil Durk',
#   'external_url': 'https://api.spotify.com/v1/artists/3hcs9uc56yIGFCSy9leWe7'},
#  {'artist_id': '6l3HvQ5sa6mXTsMTB19rO5',
#   'artist_name': 'J. Cole',
#   'external_url': 'https://api.spotify.com/v1/artists/6l3HvQ5sa6mXTsMTB19rO5'},
#  {'artist_id': '4oUHIQIBe0LHzYfvXNW4QM',
#   'artist_name': 'Morgan Wallen',
#   'external_url': 'https://api.spotify.com/v1/artists/4oUHIQIBe0LHzYfvXNW4QM'},
#  {'artist_id': '64tJ2EAv1R6UaZqc4iOCyj',
#   'artist_name': 'YOASOBI',
#   'external_url': 'https://api.spotify.com/v1/artists/64tJ2EAv1R6UaZqc4iOCyj'},
#  {'artist_id': '0XeEobZplHxzM9QzFQWLiR',
#   'artist_name': 'Eslabon Armado',
#   'external_url': 'https://api.spotify.com/v1/artists/0XeEobZplHxzM9QzFQWLiR'},
#  {'artist_id': '12GqGscKJx3aE4t07u7eVZ',
#   'artist_name': 'Peso Pluma',
#   'external_url': 'https://api.spotify.com/v1/artists/12GqGscKJx3aE4t07u7eVZ'},
#  {'artist_id': '3TVXtAsR1Inumwj472S9r4',
# ...

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_popularity = row['track']['popularity']
    song_duration_ms = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    
    song_element = {'song_id': song_id, 'song_name': song_name, 
                   'duration_ms': song_duration_ms, 'url': song_url,
                   'popularity': song_popularity, 'song_added': song_added,
                   'album_id': album_id, 'artist_id': artist_id}
    song_list.append(song_element)

# %%
song_list
# Out:
# [{'song_id': '6HgWWaMu31KdOpEG5l28BG',
#   'song_name': 'All My Life (feat. J. Cole)',
#   'duration_ms': 223878,
#   'url': 'https://open.spotify.com/track/6HgWWaMu31KdOpEG5l28BG',
#   'popularity': 90,
#   'song_added': '2023-05-16T06:56:13Z',
#   'album_id': '0lZQagJ5r0crB35zphSD4A',
#   'artist_id': '3hcs9uc56yIGFCSy9leWe7'},
#  {'song_id': '59uQI0PADDKeE6UZDTJEe8',
#   'song_name': 'Last Night',
#   'duration_ms': 163854,
#   'url': 'https://open.spotify.com/track/59uQI0PADDKeE6UZDTJEe8',
#   'popularity': 90,
#   'song_added': '2023-05-11T23:39:20Z',
#   'album_id': '7fOmdhRrRohTzToL617xkk',
#   'artist_id': '4oUHIQIBe0LHzYfvXNW4QM'},
#  {'song_id': '7ovUcF5uHTBRzUpB6ZOmvt',
#   'song_name': 'アイドル',
#   'duration_ms': 213233,
#   'url': 'https://open.spotify.com/track/7ovUcF5uHTBRzUpB6ZOmvt',
#   'popularity': 90,
#   'song_added': '2023-05-11T23:39:20Z',
#   'album_id': '7yMkS4NCpG0FH6NoaH3F0a',
#   'artist_id': '64tJ2EAv1R6UaZqc4iOCyj'},
# ...

# %%
album_df = pd.DataFrame.from_dict(album_list)
album_df = album_df.drop_duplicates(subset=['album_id'])
album_df.head()
# Out:
#                  album_id                   album_name album_release_date  \
# 0  0lZQagJ5r0crB35zphSD4A  All My Life (feat. J. Cole)         2023-05-12
# 1  7fOmdhRrRohTzToL617xkk    3 Songs At A Time Sampler         2023-01-31
# 2  7yMkS4NCpG0FH6NoaH3F0a                         アイドル         2023-04-12
# 3  3Mm1P5CEEAiuJqBclr2EyU              Ella Baila Sola         2023-03-16
# 4  67WUCOjyl44d8fAFzHONjW              Search & Rescue         2023-04-07
#
#    album_total_tracks                                          album_url
# 0                   1  https://open.spotify.com/album/0lZQagJ5r0crB35...
# 1                   3  https://open.spotify.com/album/7fOmdhRrRohTzTo...
# 2                   1  https://open.spotify.com/album/7yMkS4NCpG0FH6N...
# 3                   1  https://open.spotify.com/album/3Mm1P5CEEAiuJqB...
# 4                   1  https://open.spotify.com/album/67WUCOjyl44d8fA...

# %%
artist_df = pd.DataFrame.from_dict(artist_list)
artist_df = artist_df.drop_duplicates(subset = ['artist_id'])
artist_df.head()
# Out:
#                 artist_id     artist_name  \
# 0  3hcs9uc56yIGFCSy9leWe7        Lil Durk
# 1  6l3HvQ5sa6mXTsMTB19rO5         J. Cole
# 2  4oUHIQIBe0LHzYfvXNW4QM   Morgan Wallen
# 3  64tJ2EAv1R6UaZqc4iOCyj         YOASOBI
# 4  0XeEobZplHxzM9QzFQWLiR  Eslabon Armado
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/3hcs9uc56yI...
# 1  https://api.spotify.com/v1/artists/6l3HvQ5sa6m...
# 2  https://api.spotify.com/v1/artists/4oUHIQIBe0L...
# 3  https://api.spotify.com/v1/artists/64tJ2EAv1R6...
# 4  https://api.spotify.com/v1/artists/0XeEobZplHx...

# %%
song_df = pd.DataFrame.from_dict(song_list)
song_df = song_df.drop_duplicates(subset = ['song_id'])
song_df.head()
# Out:
#                   song_id                    song_name  duration_ms  \
# 0  6HgWWaMu31KdOpEG5l28BG  All My Life (feat. J. Cole)       223878
# 1  59uQI0PADDKeE6UZDTJEe8                   Last Night       163854
# 2  7ovUcF5uHTBRzUpB6ZOmvt                         アイドル       213233
# 3  3dnP0JxCgygwQH9Gm7q7nb              Ella Baila Sola       165671
# 4  7aRCf5cLOFN1U7kvtChY1G              Search & Rescue       272112
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/6HgWWaMu31KdOpE...          90
# 1  https://open.spotify.com/track/59uQI0PADDKeE6U...          90
# 2  https://open.spotify.com/track/7ovUcF5uHTBRzUp...          90
# 3  https://open.spotify.com/track/3dnP0JxCgygwQH9...          99
# 4  https://open.spotify.com/track/7aRCf5cLOFN1U7k...          91
#
#              song_added                album_id               artist_id
# 0  2023-05-16T06:56:13Z  0lZQagJ5r0crB35zphSD4A  3hcs9uc56yIGFCSy9leWe7
# ...

# %%
# convert release_date to datetime format
album_df['album_release_date'] = pd.to_datetime(album_df['album_release_date'])

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 86 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   album_id            86 non-null     object
#  1   album_name          86 non-null     object
#  2   album_release_date  86 non-null     datetime64[ns]
#  3   album_total_tracks  86 non-null     int64
#  4   album_url           86 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 4.0+ KB

# %%
song_df['song_added'] = pd.to_datetime(song_df['song_added'])

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      100 non-null    object
#  1   song_name    100 non-null    object
#  2   duration_ms  100 non-null    int64
#  3   url          100 non-null    object
#  4   popularity   100 non-null    int64
#  5   song_added   100 non-null    datetime64[ns, UTC]
#  6   album_id     100 non-null    object
#  7   artist_id    100 non-null    object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 7.0+ KB
